# %% [markdown]
# <a href="https://colab.research.google.com/github/Viny2030/mi_proyecto/blob/main/datasetlibro_balances.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###-I -Rubro Caja

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.4.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.2)
# Downloading faker-37.4.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.7 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-37.4.0

# %% [markdown]
# ###-ALGORITMO-I-

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicialización
fake_es = Faker('es_AR')
np.random.seed(42)
random.seed(42)
Faker.seed(42)

# Parámetros
num_registros = 30
responsables = [fake_es.name() for _ in range(10)]
tipos_transaccion = ['Venta', 'Gasto']
metodos_pago = ['Efectivo', 'Tarjeta de Débito', 'Tarjeta de Crédito', 'Transferencia']
categorias_productos = ['Electrónica', 'Alimentos', 'Ropa', 'Accesorios', 'Juguetes']
saldo = 50000

# Lista de registros
registros = []

for i in range(num_registros):
    # Fecha aleatoria dentro de los últimos 6 meses
    fecha_hora_transaccion = fake_es.date_time_between(start_date='-6M', end_date='now')
    tipo_transaccion = random.choice(tipos_transaccion)
    monto = round(random.uniform(1000, 15000), 2)

    # Ajuste del saldo
    if tipo_transaccion == 'Venta':
        saldo += monto
    else:
        saldo -= monto

    registro = {
        'id_transaccion': i + 1,
        'fecha_hora': fecha_hora_transaccion.strftime('%Y-%m-%d %H:%M:%S'),
        'tipo_transaccion': tipo_transaccion,
        'metodo_pago': random.choice(metodos_pago),
        'monto': monto,
        'saldo_acumulado': round(saldo, 2),
        'cajero_id': fake_es.random_int(min=1, max=10),
        'numero_ticket': fake_es.unique.bothify(text='TK-########'),
        'cliente_id': fake_es.random_int(min=1000, max=9999) if random.random() > 0.3 else None,
        'producto_categoria': random.choice(categorias_productos) if tipo_transaccion == 'Venta' else None,
        'descripcion': fake_es.sentence(nb_words=6) if tipo_transaccion == 'Gasto' else None,
        'responsable': random.choice(responsables)
    }

    registros.append(registro)

# Convertir a DataFrame
df_transacciones = pd.DataFrame(registros)

# Ordenar por fecha
df_transacciones.sort_values(by='fecha_hora', inplace=True)
df_transacciones.reset_index(drop=True, inplace=True)

# Mostrar muestra
##print(df_transacciones.head())

# Guardar si deseas
df_transacciones.to_csv('auditoria_caja.csv', index=False)
df_transacciones
# Out:
#     id_transaccion           fecha_hora tipo_transaccion         metodo_pago  \
# 0               29  2025-01-05 15:39:24            Gasto       Transferencia
# 1               13  2025-01-06 15:44:51            Gasto            Efectivo
# 2               23  2025-01-25 18:18:34            Venta  Tarjeta de Crédito
# 3               18  2025-01-27 05:24:33            Gasto            Efectivo
# 4               12  2025-01-27 10:18:17            Venta       Transferencia
# 5               28  2025-02-06 22:27:39            Gasto   Tarjeta de Débito
# 6               15  2025-02-07 20:00:50            Gasto       Transferencia
# 7               14  2025-02-09 02:20:06            Gasto            Efectivo
# 8               30  2025-02-09 08:36:00            Venta   Tarjeta de Débito
# 9                5  2025-02-12 20:27:16            Venta  Tarjeta de Crédito
# 10              17  2025-02-14 01:52:57            Gasto       Transferencia
# 11              26  2025-02-14 22:36:53            Venta            Efectivo
# 12               6  2025-02-19 08:35:42            Gasto  Tarjeta de Crédito
# 13              21  2025-02-22 14:44:09            Gasto  Tarjeta de Crédito
# 14              27  2025-02-25 04:39:48            Venta       Transferencia
# 15              19  2025-03-01 02:22:46            Venta       Transferencia
# 16              24  2025-03-02 14:34:04            Venta   Tarjeta de Débito
# 13               None                  Magnam dolorum tenetur amet odio.
# 14          Alimentos                                               None
# 15         Accesorios                                               None
# 16           Juguetes                                               None
# 17           Juguetes                                               None
# 18               Ropa                                               None
# 19               None  Voluptates rem minus pariatur mollitia ut aut ...
# 20               None                         Beatae facilis voluptates.
# 21          Alimentos                                               None
# 22           Juguetes                                               None
# 23               None                      Magni autem numquam sapiente.
# 24               None                 Consectetur labore mollitia eaque.
# 25          Alimentos                                               None
# 26          Alimentos                                               None
# 27          Alimentos                                               None
# 28               None                       Ratione autem sit similique.
# 29               Ropa                                               None
#
#                         responsable
# 0        Juan Bautista Martina Diaz
# 1               Benjamin Perez Diaz
# 2                   Bautista Garcia
# 3                     Martina Gomez
# 4        Juan Bautista Martina Diaz
# 5   Felipe Maximiliano Romero Gomez
# 6              Benicio Romero Perez
# 7                   Bautista Garcia
# 8             Amparo Paez Rodriguez
# 9             Amparo Paez Rodriguez
# 10                    Martina Gomez
# 11            Amparo Paez Rodriguez
# 12             Benicio Romero Perez
# 13  Felipe Maximiliano Romero Gomez
# 14             Dr(a). Delfina Nuñez
# 15  Felipe Maximiliano Romero Gomez
# 16              Benjamin Perez Diaz
# 17             Dr(a). Delfina Nuñez
# 18                  Bautista Garcia
# 19            Amparo Paez Rodriguez
# 20  Felipe Maximiliano Romero Gomez
# 21            Amparo Paez Rodriguez
# 22             Dr(a). Delfina Nuñez
# 23       Juan Bautista Martina Diaz
# 24           Alejo Fernandez Flores
# 25           Sebastian Rojas Valdez
# 26       Juan Bautista Martina Diaz
# 27           Sebastian Rojas Valdez
# 28             Dr(a). Delfina Nuñez
# 29             Dr(a). Delfina Nuñez

# %% [markdown]
# ### Algoritmo II

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# --- Generar datos simulados ---
fake = Faker('es_AR')
np.random.seed(123)
random.seed(123)

num_transacciones = 30
tipos_transaccion = ['Débito', 'Crédito']
conceptos_banco = ['Transferencia recibida', 'Transferencia enviada', 'Pago proveedor', 'Cobro cliente', 'Intereses', 'Comisión bancaria', 'Depósito efectivo']
conceptos_contables = ['Pago proveedor', 'Cobro cliente', 'Intereses ganados', 'Comisión pagada', 'Depósito registrado']

def generar_fecha():
    return fake.date_between(start_date='-30d', end_date='today')

movimientos_banco = []
movimientos_contables = []

for i in range(num_transacciones):
    fecha = generar_fecha()
    tipo = random.choice(tipos_transaccion)
    monto = round(random.uniform(500, 10000), 2)
    concepto_banco = random.choice(conceptos_banco)
    concepto_contable = random.choice(conceptos_contables)

    movimientos_banco.append({
        'id_banco': i + 1,
        'fecha': fecha,
        'tipo': tipo,
        'concepto_banco': concepto_banco,
        'monto_banco': monto,
        'referencia_banco': fake.unique.bothify('BNK-########')
    })

    # 90% de chance de tener contrapartida contable
    if random.random() > 0.1:
        monto_contable = monto if random.random() > 0.2 else round(monto + random.uniform(-100, 100), 2)
        movimientos_contables.append({
            'id_contable': i + 1,
            'fecha': fecha,
            'tipo': tipo,
            'concepto_contable': concepto_contable,
            'monto_contable': monto_contable,
            'referencia_contable': fake.unique.bothify('CNT-########')
        })

df_banco = pd.DataFrame(movimientos_banco)
df_contabilidad = pd.DataFrame(movimientos_contables)

# --- Conciliación aproximada ---
# Merge tolerando diferencias de hasta $50 y por fecha/tipo
tolerancia = 50

# Expandir el dataset contable para permitir combinación múltiple (simulación)
df_merged = pd.merge(df_banco, df_contabilidad,
                     on=['fecha', 'tipo'],
                     how='outer', suffixes=('_banco', '_contable'))

# Calcular diferencia
df_merged['diferencia_monto'] = np.abs(df_merged['monto_banco'] - df_merged['monto_contable'])

# Marcar conciliación
df_merged['conciliado'] = df_merged['diferencia_monto'] <= tolerancia

# Llenar NaNs en campos faltantes por outer merge
df_merged['conciliado'] = df_merged['conciliado'].fillna(False)

# Mostrar resultados
df_merged[['fecha', 'tipo', 'monto_banco', 'monto_contable', 'diferencia_monto', 'conciliado']].head(10)

# Guardar si lo deseas
df_merged.to_csv('conciliacion_bancaria.csv', index=False)
df_merged
# Out:
#     id_banco       fecha     tipo          concepto_banco  monto_banco  \
# 0         28  2025-06-06  Crédito               Intereses       908.73
# 1         18  2025-06-06   Débito  Transferencia recibida      4615.40
# 2          4  2025-06-08  Crédito          Pago proveedor      1163.83
# 3         20  2025-06-10  Crédito       Comisión bancaria      3809.49
# 4          6  2025-06-13  Crédito  Transferencia recibida      4958.28
# 5         14  2025-06-13   Débito           Cobro cliente      6568.61
# 6         26  2025-06-15   Débito  Transferencia recibida      3763.92
# 7         25  2025-06-16  Crédito       Depósito efectivo      3386.15
# 8          3  2025-06-17  Crédito   Transferencia enviada      7166.05
# 9          3  2025-06-17  Crédito   Transferencia enviada      7166.05
# 10        24  2025-06-17  Crédito   Transferencia enviada      1089.53
# 11        24  2025-06-17  Crédito   Transferencia enviada      1089.53
# 12        12  2025-06-17   Débito  Transferencia recibida      2296.09
# 13        27  2025-06-18  Crédito               Intereses      1382.14
# 14        23  2025-06-18   Débito          Pago proveedor      5581.75
# 15         7  2025-06-19   Débito       Comisión bancaria      8302.09
# 16         2  2025-06-20   Débito               Intereses      4101.68
# 17         1  2025-06-21   Débito       Depósito efectivo      3042.93
# 18        29  2025-06-22   Débito               Intereses      2344.55
# 19        13  2025-06-24  Crédito           Cobro cliente      9976.75
# 20        16  2025-06-25   Débito       Depósito efectivo       699.58
# 21        15  2025-06-26   Débito           Cobro cliente      9923.60
# 22        10  2025-06-27   Débito  Transferencia recibida      7395.36
# 23        11  2025-06-28  Crédito       Comisión bancaria      8897.21
# 24        17  2025-06-29  Crédito               Intereses       503.38
# 25         9  2025-06-30  Crédito           Cobro cliente      5445.79
# 26        30  2025-07-01  Crédito               Intereses      1295.54
# 27         8  2025-07-01   Débito       Depósito efectivo      4283.26
# 28         8  2025-07-01   Débito       Depósito efectivo      4283.26
# 29        21  2025-07-01   Débito   Transferencia enviada      4035.04
# 30        21  2025-07-01   Débito   Transferencia enviada      4035.04
# 31        19  2025-07-04  Crédito          Pago proveedor       776.80
# 32        19  2025-07-04  Crédito          Pago proveedor       776.80
# 33        22  2025-07-04  Crédito   Transferencia enviada      5606.60
# 34        22  2025-07-04  Crédito   Transferencia enviada      5606.60
# 35         5  2025-07-05   Débito  Transferencia recibida      8005.68
#
#    referencia_banco  id_contable    concepto_contable  monto_contable  \
# 0      BNK-43244510         28.0       Pago proveedor          908.73
# 1      BNK-40268117         18.0  Depósito registrado         4615.40
# 2      BNK-45961586          4.0      Comisión pagada         1197.26
# 3      BNK-24998569         20.0        Cobro cliente         3809.49
# 4      BNK-69222196          6.0    Intereses ganados         4958.28
# 5      BNK-82675869         14.0        Cobro cliente         6568.61
# 6      BNK-59910229         26.0  Depósito registrado         3763.92
# 7      BNK-22961201         25.0       Pago proveedor         3386.15
# 8      BNK-27028951          3.0       Pago proveedor         7166.05
# 9      BNK-27028951         24.0      Comisión pagada         1089.53
# 10     BNK-49368998          3.0       Pago proveedor         7166.05
# 11     BNK-49368998         24.0      Comisión pagada         1089.53
# 12     BNK-49651370          NaN                  NaN             NaN
# 13     BNK-38156149         27.0        Cobro cliente         1382.14
# 14     BNK-60494519         23.0  Depósito registrado         5599.61
# 15     BNK-07482175          7.0  Depósito registrado         8302.09
# 16     BNK-58867533          2.0    Intereses ganados         4028.69
# 17     BNK-21465840          1.0      Comisión pagada         3042.93
# 18     BNK-51606071          NaN                  NaN             NaN
# 19     BNK-85931746         13.0  Depósito registrado         9976.75
# 20     BNK-90053293         16.0    Intereses ganados          699.58
# 21     BNK-37735158         15.0      Comisión pagada         9850.55
# 22     BNK-14562328         10.0      Comisión pagada         7362.74
# 23     BNK-51712368         11.0      Comisión pagada         8897.21
# 24     BNK-90422842         17.0       Pago proveedor          503.38
# 25     BNK-43953394          9.0    Intereses ganados         5445.79
# 26     BNK-96966416         30.0  Depósito registrado         1295.54
# 27     BNK-13695944          8.0  Depósito registrado         4283.26
# 28     BNK-13695944         21.0       Pago proveedor         4035.04
# 29     BNK-83673657          8.0  Depósito registrado         4283.26
# 30     BNK-83673657         21.0       Pago proveedor         4035.04
# 31     BNK-08470076         19.0    Intereses ganados          789.12
# 32     BNK-08470076         22.0    Intereses ganados         5606.60
# 33     BNK-71111615         19.0    Intereses ganados          789.12
# 34     BNK-71111615         22.0    Intereses ganados         5606.60
# 35     BNK-16117240          5.0    Intereses ganados         8005.68
#
#    referencia_contable  diferencia_monto  conciliado
# 0         CNT-76226838              0.00        True
# 1         CNT-75891783              0.00        True
# 2         CNT-57809134             33.43        True
# 3         CNT-84789611              0.00        True
# 4         CNT-93792374              0.00        True
# 5         CNT-26179640              0.00        True
# 6         CNT-01476797              0.00        True
# 7         CNT-83667525              0.00        True
# 8         CNT-71870262              0.00        True
# 9         CNT-09402445           6076.52       False
# 10        CNT-71870262           6076.52       False
# 11        CNT-09402445              0.00        True
# 12                 NaN               NaN       False
# 13        CNT-78403690              0.00        True
# 14        CNT-83273158             17.86        True
# 15        CNT-94647436              0.00        True
# 16        CNT-96360576             72.99       False
# 17        CNT-44997278              0.00        True
# 18                 NaN               NaN       False
# 19        CNT-12004711              0.00        True
# 20        CNT-18393352              0.00        True
# 21        CNT-50643171             73.05       False
# 22        CNT-58842474             32.62        True
# 23        CNT-51604817              0.00        True
# 24        CNT-10205395              0.00        True
# 25        CNT-21047095              0.00        True
# 26        CNT-05297516              0.00        True
# 27        CNT-06409097              0.00        True
# 28        CNT-66156545            248.22       False
# 29        CNT-06409097            248.22       False
# 30        CNT-66156545              0.00        True
# 31        CNT-61771159             12.32        True
# 32        CNT-28098851           4829.80       False
# 33        CNT-61771159           4817.48       False
# 34        CNT-28098851              0.00        True
# 35        CNT-05045562              0.00        True

# %% [markdown]
# ### Algoritmo III

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicializar Faker y semillas
np.random.seed(123)
random.seed(123)
fake = Faker('es_AR')
Faker.seed(123)

# Parámetros
num_clientes = 30
num_facturas = 100
tipos_cliente = ['Empresa', 'Individuo']
estados_posibles = ['Pagada', 'Pendiente', 'Vencida', 'Parcialmente Pagada']
condiciones_pago = [0, 15, 30, 60]  # en días

# Generar clientes simulados
clientes = []
for i in range(num_clientes):
    clientes.append({
        'cliente_id': 1000 + i,
        'nombre': fake.company() if random.random() > 0.3 else fake.name(),
        'tipo': random.choice(tipos_cliente),
        'cuit': fake.unique.bothify(text='##-########-#')
    })

# Generar facturas (cuentas a cobrar)
facturas = []
for i in range(num_facturas):
    cliente = random.choice(clientes)
    fecha_emision = fake.date_between(start_date='-90d', end_date='today')
    dias_pago = random.choice(condiciones_pago)
    fecha_vencimiento = fecha_emision + timedelta(days=dias_pago)
    estado = random.choices(estados_posibles, weights=[0.4, 0.3, 0.2, 0.1])[0]
    monto_total = round(random.uniform(5000, 150000), 2)

    # Determinar monto pagado y fecha de pago según el estado
    if estado == 'Pagada':
        monto_pagado = monto_total
        fecha_pago = fecha_emision if dias_pago == 0 else fecha_emision + timedelta(days=random.randint(0, dias_pago))
    elif estado == 'Parcialmente Pagada':
        monto_pagado = round(monto_total * random.uniform(0.1, 0.9), 2)
        fecha_pago = fecha_emision if dias_pago == 0 else fecha_emision + timedelta(days=random.randint(0, dias_pago))
    else:
        monto_pagado = 0.0
        fecha_pago = None

    saldo_pendiente = round(monto_total - monto_pagado, 2)

    facturas.append({
        'factura_id': f'F-{10000 + i}',
        'cliente_id': cliente['cliente_id'],
        'fecha_emision': fecha_emision,
        'fecha_vencimiento': fecha_vencimiento,
        'fecha_pago': fecha_pago,
        'estado': estado,
        'monto_total': monto_total,
        'monto_pagado': monto_pagado,
        'saldo_pendiente': saldo_pendiente,
        'condicion_pago_dias': dias_pago
    })

# Convertir a DataFrame
df_facturas = pd.DataFrame(facturas)
df_clientes = pd.DataFrame(clientes)

# Unir para obtener listado final
df_cuentas_cobrar = pd.merge(df_facturas, df_clientes, on='cliente_id')

# Ordenar por fecha de vencimiento
df_cuentas_cobrar.sort_values(by='fecha_vencimiento', inplace=True)

# Mostrar muestra
df_cuentas_cobrar

# Guardar a CSV si lo necesitás
df_cuentas_cobrar.to_csv("listado_cuentas_a_cobrar.csv", index=False)
df_cuentas_cobrar
# Out:
#    factura_id  cliente_id fecha_emision fecha_vencimiento  fecha_pago  \
# 13    F-10013        1026    2025-04-07        2025-04-07        None
# 73    F-10073        1010    2025-04-12        2025-04-12  2025-04-12
# 72    F-10072        1004    2025-04-13        2025-04-13  2025-04-13
# 43    F-10043        1015    2025-04-14        2025-04-14        None
# 80    F-10080        1007    2025-04-17        2025-04-17  2025-04-17
# ..        ...         ...           ...               ...         ...
# 55    F-10055        1025    2025-06-16        2025-08-15  2025-08-03
# 65    F-10065        1028    2025-06-16        2025-08-15        None
# 28    F-10028        1026    2025-06-22        2025-08-21  2025-08-14
# 27    F-10027        1023    2025-06-23        2025-08-22        None
# 71    F-10071        1006    2025-06-26        2025-08-25  2025-07-26
#
#        estado  monto_total  monto_pagado  saldo_pendiente  \
# 13    Vencida     61145.24          0.00         61145.24
# 73     Pagada     36765.58      36765.58             0.00
# 72     Pagada    120133.09     120133.09             0.00
# 43  Pendiente     83577.29          0.00         83577.29
# 80     Pagada     14367.43      14367.43             0.00
# ..        ...          ...           ...              ...
# 55     Pagada     87651.11      87651.11             0.00
# 65    Vencida     46583.94          0.00         46583.94
# 28     Pagada    137602.25     137602.25             0.00
# 27    Vencida     42243.50          0.00         42243.50
# 71     Pagada     23291.31      23291.31             0.00
#
#     condicion_pago_dias                         nombre       tipo  \
# 13                    0                   Medina Group  Individuo
# 73                    0             Fernandez-Ferreyra    Empresa
# 72                    0                     Farias Ltd    Empresa
# 43                    0              Mansilla and Sons  Individuo
# 80                    0      Facundo Benjamin Figueroa  Individuo
# ..                  ...                            ...        ...
# 55                   60  Gonzalez, Blanco and Martinez    Empresa
# 65                   60                    Alvarez Inc    Empresa
# 28                   60                   Medina Group  Individuo
# 27                   60                 Cabrera-Castro    Empresa
# 71                   60    Garcia, Aguirre and Coronel    Empresa
#
#              cuit
# 13  38-66836170-4
# 73  46-52858129-6
# 72  21-74255861-7
# 43  90-99759105-7
# 80  46-60191851-1
# ..            ...
# 55  64-24145380-5
# 65  18-19513626-2
# 28  38-66836170-4
# 27  38-16671096-6
# 71  38-72287670-0
#
# [100 rows x 13 columns]

# %% [markdown]
# ### algoritmo IV

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicialización
np.random.seed(42)
random.seed(42)
fake = Faker('es_AR')
Faker.seed(42)

# Parámetros
num_registros = 30
tipos_gasto = ['Alquiler', 'Seguro', 'Publicidad', 'Licencias de software', 'Mantenimiento']
proveedores = [fake.company() for _ in range(10)]

# Generar datos
prepagos = []

for i in range(num_registros):
    proveedor = random.choice(proveedores)
    tipo = random.choice(tipos_gasto)
    fecha_pago = fake.date_between(start_date='-60d', end_date='today')

    # Duración del servicio prepago (1 a 12 meses)
    duracion_meses = random.choice([1, 3, 6, 12])
    fecha_inicio = fecha_pago + timedelta(days=random.randint(0, 15))
    fecha_fin = fecha_inicio + pd.DateOffset(months=duracion_meses)

    # Monto proporcional al tiempo
    monto_total = round(random.uniform(5000, 200000), 2)
    monto_mensual = round(monto_total / duracion_meses, 2)

    prepagos.append({
        'id_prepago': f'PP-{1000 + i}',
        'tipo_gasto': tipo,
        'proveedor': proveedor,
        'fecha_pago': fecha_pago,
        'fecha_inicio_servicio': fecha_inicio,
        'fecha_fin_servicio': fecha_fin.date(),
        'duracion_meses': duracion_meses,
        'monto_total': monto_total,
        'monto_mensual': monto_mensual,
        'moneda': 'ARS',
        'estado': 'Activo' if fecha_fin > datetime.today() else 'Consumido'
    })

# Convertir a DataFrame
# 22  2025-05-23            2025-06-02         2025-12-02               6
# 23  2025-07-02            2025-07-02         2026-07-02              12
# 24  2025-06-14            2025-06-17         2025-09-17               3
# 25  2025-06-12            2025-06-16         2025-09-16               3
# 26  2025-05-17            2025-05-27         2025-06-27               1
# 27  2025-06-19            2025-06-26         2025-12-26               6
# 28  2025-05-16            2025-05-31         2025-06-30               1
# 29  2025-05-29            2025-06-13         2025-09-13               3
#
#     monto_total  monto_mensual moneda     estado
# 0      48526.09        8087.68    ARS     Activo
# 1      11197.62       11197.62    ARS     Activo
# 2     114442.79       38147.60    ARS     Activo
# 3     119906.81       39968.94    ARS     Activo
# 4      59184.91        4932.08    ARS     Activo
# 5      79085.82       79085.82    ARS     Activo
# 6     147297.70       24549.62    ARS     Activo
# 7     112647.92        9387.33    ARS     Activo
# 8      13935.75        4645.25    ARS     Activo
# 9     173964.32      173964.32    ARS     Activo
# 10     36717.55        3059.80    ARS     Activo
# 11    123780.55       20630.09    ARS     Activo
# 12     95140.74       31713.58    ARS     Activo
# 13    169356.12       56452.04    ARS     Activo
# 14     83227.13       83227.13    ARS  Consumido
# 15    132810.54       22135.09    ARS     Activo
# 16     32227.91       10742.64    ARS     Activo
# 17    180075.46       30012.58    ARS     Activo
# 18    104357.63       34785.88    ARS     Activo
# 19    127351.98      127351.98    ARS  Consumido
# 20     79415.76       79415.76    ARS     Activo
# 21    137655.27       22942.54    ARS     Activo
# 22     26752.67        4458.78    ARS     Activo
# 23    190994.11       15916.18    ARS     Activo
# 24    174751.12       58250.37    ARS     Activo
# 25     77913.20       25971.07    ARS     Activo
# 26    100278.11      100278.11    ARS  Consumido
# 27     16295.41        2715.90    ARS     Activo
# 28    164124.53      164124.53    ARS  Consumido
# 29    189635.49       63211.83    ARS     Activo

# %% [markdown]
# ### Algoritmo V

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicialización
np.random.seed(42)
random.seed(42)
fake = Faker('es_AR')
Faker.seed(42)

# Parámetros
num_items = 30
categorias = ['Metales', 'Plásticos', 'Químicos', 'Textiles', 'Madera', 'Papel', 'Vidrio']
unidades = ['kg', 'litros', 'm3', 'unidades', 'rollos']

# Generar datos de inventario
inventario = []

for i in range(num_items):
    id_material = f'MP-{1000 + i}'
    descripcion = fake.word().capitalize() + " " + fake.word()
    categoria = random.choice(categorias)
    unidad = random.choice(unidades)

    cantidad_stock = round(random.uniform(50, 1000), 2)
    punto_reposicion = round(random.uniform(30, 150), 2)
    costo_unitario = round(random.uniform(100, 5000), 2)
    valor_total = round(cantidad_stock * costo_unitario, 2)

    fecha_entrada = fake.date_between(start_date='-90d', end_date='-10d')
    fecha_salida = fecha_entrada + timedelta(days=random.randint(1, 30))

    inventario.append({
        'id_material': id_material,
        'descripcion': descripcion,
        'categoria': categoria,
        'unidad_medida': unidad,
        'cantidad_stock': cantidad_stock,
        'punto_reposicion': punto_reposicion,
        'costo_unitario': costo_unitario,
        'valor_total': valor_total,
        'fecha_ultima_entrada': fecha_entrada,
        'fecha_ultima_salida': fecha_salida
    })

# Convertir a DataFrame
df_inventario_mp = pd.DataFrame(inventario)



#
#    fecha_ultima_entrada fecha_ultima_salida
# 0            2025-04-09          2025-05-03
# 1            2025-04-24          2025-05-01
# 2            2025-06-05          2025-06-28
# 3            2025-05-24          2025-05-25
# 4            2025-04-14          2025-05-09
# 5            2025-05-25          2025-06-14
# 6            2025-06-03          2025-06-16
# 7            2025-05-10          2025-05-22
# 8            2025-04-29          2025-05-09
# 9            2025-06-01          2025-06-28
# 10           2025-04-19          2025-05-19
# 11           2025-04-14          2025-04-20
# 12           2025-06-13          2025-06-21
# 13           2025-06-10          2025-06-12
# 14           2025-04-16          2025-05-05
# 15           2025-05-21          2025-06-11
# 16           2025-06-16          2025-06-25
# 17           2025-04-22          2025-04-27
# 18           2025-05-29          2025-06-19
# 19           2025-06-14          2025-06-29
# 20           2025-04-29          2025-05-23
# 21           2025-04-20          2025-04-30
# 22           2025-05-30          2025-06-08
# 23           2025-05-28          2025-06-24
# 24           2025-04-20          2025-05-08
# 25           2025-05-13          2025-05-17
# 26           2025-06-01          2025-06-04
# 27           2025-05-02          2025-05-07
# 28           2025-06-11          2025-07-01
# 29           2025-04-28          2025-05-21

# %% [markdown]
# ### Algoritmo VI

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicialización
np.random.seed(42)
random.seed(42)
fake = Faker('es_AR')
Faker.seed(42)

# Parámetros
num_registros = 60
etapas_produccion = ['Corte', 'Ensamblado', 'Soldadura', 'Pintura', 'Control de calidad']
lineas_produccion = ['Línea A', 'Línea B', 'Línea C']
productos = ['Silla', 'Mesa', 'Estantería', 'Armario', 'Puerta']

# Generar datos
productos_proceso = []

for i in range(num_registros):
    producto = random.choice(productos)
    lote = f'L-{fake.random_int(min=1000, max=9999)}'
    etapa = random.choice(etapas_produccion)
    linea = random.choice(lineas_produccion)
    cantidad_en_proceso = random.randint(10, 200)
    fecha_inicio = fake.date_between(start_date='-30d', end_date='-1d')
    duracion_estimada = random.randint(1, 10)  # en días
    fecha_estim_termino = fecha_inicio + timedelta(days=duracion_estimada)
    avance_porcentaje = random.randint(10, 95)

    productos_proceso.append({
        'id_proceso': f'WIP-{1000 + i}',
        'producto': producto,
        'lote': lote,
        'etapa_actual': etapa,
        'linea_produccion': linea,
        'cantidad_en_proceso': cantidad_en_proceso,
        'fecha_inicio': fecha_inicio,
        'fecha_estim_termino': fecha_estim_termino,
        'avance_porcentaje': avance_porcentaje,
        'estado': 'En proceso' if avance_porcentaje < 100 else 'Terminado'
    })

# Convertir a DataFrame
df_inventario_pp = pd.DataFrame(productos_proceso)



# Guardar si lo necesitás
df_inventario_pp.to_csv("productos_en_proceso.csv", index=False)
df_inventario_pp
# Out:
#    id_proceso    producto    lote        etapa_actual linea_produccion  \
# 0    WIP-1000       Silla  L-2824               Corte          Línea C
# 1    WIP-1001        Mesa  L-5506               Corte          Línea C
# 2    WIP-1002      Puerta  L-3286             Pintura          Línea A
# 3    WIP-1003        Mesa  L-9935  Control de calidad          Línea C
# 4    WIP-1004      Puerta  L-7912             Pintura          Línea A
# 5    WIP-1005       Silla  L-2535          Ensamblado          Línea C
# 6    WIP-1006        Mesa  L-9279          Ensamblado          Línea B
# 59                   99   2025-07-04          2025-07-06                 41
#
#         estado
# 0   En proceso
# 1   En proceso
# 2   En proceso
# 3   En proceso
# 4   En proceso
# 5   En proceso
# 6   En proceso
# 7   En proceso
# 8   En proceso
# 9   En proceso
# 10  En proceso
# 11  En proceso
# 12  En proceso
# 13  En proceso
# 14  En proceso
# 15  En proceso
# 16  En proceso
# 17  En proceso
# 18  En proceso
# 19  En proceso
# 20  En proceso
# 21  En proceso
# 22  En proceso
# 23  En proceso
# 24  En proceso
# 25  En proceso
# 26  En proceso
# 27  En proceso
# 28  En proceso
# 29  En proceso
# 30  En proceso
# 31  En proceso
# 32  En proceso
# 33  En proceso
# 34  En proceso
# 35  En proceso
# 36  En proceso
# 37  En proceso
# 38  En proceso
# 39  En proceso
# 40  En proceso
# 41  En proceso
# 42  En proceso
# 43  En proceso
# 44  En proceso
# 45  En proceso
# 46  En proceso
# 47  En proceso
# 48  En proceso
# 49  En proceso
# 50  En proceso
# 51  En proceso
# 52  En proceso
# 53  En proceso
# 54  En proceso
# 55  En proceso
# 56  En proceso
# 57  En proceso
# 58  En proceso
# 59  En proceso

# %% [markdown]
# ### Algoritmo VII

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicialización
np.random.seed(42)
random.seed(42)
fake = Faker('es_AR')
Faker.seed(42)

# Parámetros
num_registros = 30
productos = ['Silla', 'Mesa', 'Estantería', 'Armario', 'Puerta']
etapas_produccion = ['Corte', 'Ensamblado', 'Soldadura', 'Pintura', 'Control de calidad']
lineas_produccion = ['Línea A', 'Línea B', 'Línea C']

# Generar Productos en Proceso (WIP)
productos_proceso = []

for i in range(num_registros):
    producto = random.choice(productos)
    lote = f'L-{fake.random_int(min=1000, max=9999)}'
    etapa = random.choice(etapas_produccion)
    linea = random.choice(lineas_produccion)
    cantidad_total = random.randint(50, 200)
    fecha_inicio = fake.date_between(start_date='-30d', end_date='-1d')
    duracion_estimada = random.randint(5, 15)  # días estimados para terminar
    fecha_estim_termino = fecha_inicio + timedelta(days=duracion_estimada)
    avance_porcentaje = random.randint(10, 100)
    estado = 'En proceso' if avance_porcentaje < 100 else 'Terminado'
    cantidad_en_proceso = int(cantidad_total * (avance_porcentaje / 100))
    cantidad_terminada = cantidad_total - cantidad_en_proceso if estado == 'En proceso' else cantidad_total

    productos_proceso.append({
        'id_proceso': f'WIP-{1000 + i}',
        'producto': producto,
        'lote': lote,
        'etapa_actual': etapa,
        'linea_produccion': linea,
        'cantidad_total': cantidad_total,
        'cantidad_en_proceso': cantidad_en_proceso,
        'fecha_inicio': fecha_inicio,
        'fecha_estim_termino': fecha_estim_termino,
        'avance_porcentaje': avance_porcentaje,
        'estado': estado
    })

df_wip = pd.DataFrame(productos_proceso)

# Generar Productos Terminados basados en WIP terminados o parcial completados
productos_terminados = []

for _, row in df_wip.iterrows():
    # Si está terminado, todo va a terminados
    if row['estado'] == 'Terminado':
        productos_terminados.append({
            'id_terminado': f'PT-{row["id_proceso"].split("-")[1]}',
            'producto': row['producto'],
            'lote': row['lote'],
            'linea_produccion': row['linea_produccion'],
            'cantidad_terminada': row['cantidad_total'],
            'fecha_termino': row['fecha_estim_termino'] + timedelta(days=random.randint(0,3)),
            'estado': 'Almacén'
        })
    else:
        # Si está en proceso, generamos terminados solo si hay cantidad terminada > 0
        cantidad_terminada = row['cantidad_total'] - row['cantidad_en_proceso']
        if cantidad_terminada > 0:
            productos_terminados.append({
                'id_terminado': f'PT-{row["id_proceso"].split("-")[1]}',
                'producto': row['producto'],
                'lote': row['lote'],
                'linea_produccion': row['linea_produccion'],
                'cantidad_terminada': cantidad_terminada,
                'fecha_termino': row['fecha_estim_termino'] + timedelta(days=random.randint(0,3)),
                'estado': 'Almacén'
            })

df_terminados = pd.DataFrame(productos_terminados)

# Guardar CSV si querés
df_wip.to_csv('productos_en_proceso.csv', index=False)
df_terminados.to_csv('productos_terminados.csv', index=False)
df_wip
df_terminados
# Out:
#    id_terminado    producto    lote linea_produccion  cantidad_terminada  \
# 0       PT-1000       Silla  L-2824          Línea C                  75
# 1       PT-1001        Mesa  L-5506          Línea C                  29
# 2       PT-1002     Armario  L-3286          Línea A                  45
# 3       PT-1003      Puerta  L-9935          Línea A                  14
# 4       PT-1004      Puerta  L-7912          Línea A                  91
# 5       PT-1005       Silla  L-2535          Línea C                  87
# 6       PT-1006        Mesa  L-9279          Línea B                  32
# 7       PT-1007       Silla  L-4257          Línea B                  38
# 8       PT-1008      Puerta  L-9928          Línea B                  38
# 9       PT-1009      Puerta  L-8359          Línea C                  85
# 10      PT-1010        Mesa  L-1106          Línea A                  46
# 11      PT-1011  Estantería  L-3615          Línea C                  62
# 12      PT-1012  Estantería  L-6574          Línea C                  10
# 13      PT-1013       Silla  L-4527          Línea C                  55
# 14      PT-1014        Mesa  L-6514          Línea B                   3
# 15      PT-1015      Puerta  L-7224          Línea C                  82
# 16      PT-1016       Silla  L-6635          Línea B                  75
# 17      PT-1017      Puerta  L-1711          Línea A                  15
# 18      PT-1018     Armario  L-9785          Línea B                  17
# 19      PT-1019      Puerta  L-7201          Línea C                  32
# 20      PT-1020     Armario  L-5803          Línea A                  23
# 21      PT-1021       Silla  L-6925          Línea A                  63
# 22      PT-1022     Armario  L-2139          Línea A                  21
# 23      PT-1023     Armario  L-4733          Línea B                   6
# 24      PT-1024       Silla  L-2307          Línea B                  73
# 25      PT-1025     Armario  L-2654          Línea B                  13
# 26      PT-1026        Mesa  L-8428          Línea A                  33
# 27      PT-1027      Puerta  L-6977          Línea A                  31
# 28      PT-1028      Puerta  L-6820          Línea C                 117
# 29      PT-1029       Silla  L-5374          Línea B                  67
#
#    fecha_termino   estado
# 0     2025-06-14  Almacén
# 1     2025-06-19  Almacén
# 2     2025-07-08  Almacén
# 3     2025-06-16  Almacén
# 4     2025-06-21  Almacén
# 5     2025-06-23  Almacén
# 6     2025-07-02  Almacén
# 7     2025-07-02  Almacén
# 8     2025-07-03  Almacén
# 9     2025-07-02  Almacén
# 10    2025-07-05  Almacén
# 11    2025-07-04  Almacén
# 12    2025-07-01  Almacén
# 13    2025-07-19  Almacén
# 14    2025-06-25  Almacén
# 15    2025-06-16  Almacén
# 16    2025-07-02  Almacén
# 17    2025-07-08  Almacén
# 18    2025-06-18  Almacén
# 19    2025-06-20  Almacén
# 20    2025-07-13  Almacén
# 21    2025-07-09  Almacén
# 22    2025-06-18  Almacén
# 23    2025-07-04  Almacén
# 24    2025-07-07  Almacén
# 25    2025-06-26  Almacén
# 26    2025-07-09  Almacén
# 27    2025-06-17  Almacén
# 28    2025-06-25  Almacén
# 29    2025-07-01  Almacén

# %% [markdown]
# ## Algoritmo VIII-control de calidad

# %%
import numpy as np
import random

# Semilla para reproducibilidad
random.seed(42)
np.random.seed(42)

def simular_control_calidad(df_terminados):
    resultados_qc = []

    for idx, fila in df_terminados.iterrows():
        # Probabilidad de aprobar (por ejemplo, 85%)
        aprobado = np.random.choice([True, False], p=[0.85, 0.15])

        if aprobado:
            porcentaje_defectos = round(random.uniform(0, 2), 2)  # muy bajo defectos si aprueba
            observacion = 'Sin observaciones relevantes'
            estado_qc = 'Aprobado'
        else:
            porcentaje_defectos = round(random.uniform(5, 20), 2)  # defectos significativos
            observacion = random.choice([
                'Defectos en pintura',
                'Problemas de ensamblaje',
                'Daños en superficie',
                'Dimensiones fuera de tolerancia'
            ])
            estado_qc = 'Rechazado'

        resultados_qc.append({
            'id_terminado': fila['id_terminado'],
            'producto': fila['producto'],
            'lote': fila['lote'],
            'fecha_inspeccion': fila['fecha_termino'] + pd.Timedelta(days=random.randint(1,5)),
            'estado_qc': estado_qc,
            'porcentaje_defectos': porcentaje_defectos,
            'observacion': observacion
        })

    return pd.DataFrame(resultados_qc)

# Simular QC
df_control_calidad = simular_control_calidad(df_terminados)

df_control_calidad.head()
# Out:
#   id_terminado producto    lote fecha_inspeccion  estado_qc  \
# 0      PT-1000    Silla  L-2824       2025-06-15   Aprobado
# 1      PT-1001     Mesa  L-5506       2025-06-21  Rechazado
# 2      PT-1002  Armario  L-3286       2025-07-09   Aprobado
# 3      PT-1003   Puerta  L-9935       2025-06-21   Aprobado
# 4      PT-1004   Puerta  L-7912       2025-06-25   Aprobado
#
#    porcentaje_defectos                   observacion
# 0                 1.28  Sin observaciones relevantes
# 1                16.12       Problemas de ensamblaje
# 2                 0.28  Sin observaciones relevantes
# 3                 1.35  Sin observaciones relevantes
# 4                 0.17  Sin observaciones relevantes

# %% [markdown]
# ### Algortimo IX-colocaciones

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicializar
np.random.seed(123)
random.seed(123)
fake = Faker('es_AR')
Faker.seed(123)

# Parámetros
num_colocaciones = 30
tipos_colocacion = ['Préstamo', 'Inversión']
tipos_interes = ['Fijo', 'Variable']
estados = ['Vigente', 'Cancelado', 'Mora']

# Generar colocaciones
colocaciones = []

for i in range(num_colocaciones):
    tipo = random.choice(tipos_colocacion)
    monto = round(random.uniform(50000, 1000000), 2)
    tasa_interes = round(random.uniform(5, 20), 2)  # %
    tipo_tasa = random.choice(tipos_interes)
    plazo_meses = random.choice([6, 12, 24, 36, 48, 60])
    fecha_inicio = fake.date_between(start_date='-5y', end_date='-1y')
    fecha_vencimiento = fecha_inicio + timedelta(days=plazo_meses*30)
    estado = random.choices(estados, weights=[0.7, 0.2, 0.1])[0]

    colocaciones.append({
        'id_colocacion': f'CL-{1000 + i}',
        'cliente_id': fake.random_int(min=1000, max=9999),
        'tipo_colocacion': tipo,
        'monto': monto,
        'tasa_interes': tasa_interes,
        'tipo_tasa': tipo_tasa,
        'plazo_meses': plazo_meses,
        'fecha_inicio': fecha_inicio,
        'fecha_vencimiento': fecha_vencimiento,
        'estado': estado
    })

df_colocaciones = pd.DataFrame(colocaciones)
# Guardar si necesitás
df_colocaciones.to_csv('colocaciones_financieras.csv', index=False)
df_colocaciones
# Out:
#    id_colocacion  cliente_id tipo_colocacion      monto  tasa_interes  \
# 0        CL-1000        2428        Préstamo  304293.31         16.53
# 1        CL-1001        5367        Préstamo  410168.12         13.43
# 2        CL-1002        1625       Inversión  582913.91         15.53
# 3        CL-1003        6442        Préstamo  884698.82         10.66
# 4        CL-1004        1850        Préstamo  910128.72          6.39
# 5        CL-1005        6524        Préstamo  327211.44         11.46
# 6        CL-1006        5016        Préstamo  780355.01         10.15
# 7        CL-1007        8147       Inversión   61920.69         18.39
# 8        CL-1008        7186       Inversión  544578.55         11.29
# 9        CL-1009        6168        Préstamo  917963.62         14.87
# 10       CL-1010        2671       Inversión  889720.76         15.85
# 11       CL-1011        2519        Préstamo  229608.78          6.32
# 12       CL-1012        3068        Préstamo  435432.91         12.52
# 13       CL-1013        1347       Inversión  965856.21         14.45
# 14       CL-1014        8055        Préstamo  196073.59         13.05
# 15       CL-1015        5347        Préstamo  483523.31          5.32
# 16       CL-1016        1602       Inversión  652555.01          5.01
# 17       CL-1017        6627        Préstamo  128760.24         18.46
# 18       CL-1018        8912       Inversión   77680.03          9.84
# 19       CL-1019        9635       Inversión  443368.01          5.36
# 20       CL-1020        6165        Préstamo  403504.14          8.52
# 21       CL-1021        9400       Inversión  560659.56          7.19
# 22       CL-1022        9823       Inversión  541248.31         14.44
# 23       CL-1023        8964        Préstamo  482003.55          5.31
# 24       CL-1024        7873       Inversión  338615.49         16.87
# 25       CL-1025        1521        Préstamo  376392.33          6.57
# 26       CL-1026        3973       Inversión  138214.04         18.95
# 27       CL-1027        2353       Inversión  428261.67         19.07
# 28       CL-1028        5290        Préstamo  234455.13         13.47
# 29       CL-1029        6520       Inversión  576807.97          7.00
#
#    tipo_tasa  plazo_meses fecha_inicio fecha_vencimiento     estado
# 0   Variable            6   2020-09-19        2021-03-18  Cancelado
# 1   Variable            6   2023-08-02        2024-01-29    Vigente
# 2       Fijo            6   2020-12-09        2021-06-07       Mora
# 3       Fijo           24   2022-01-09        2023-12-30  Cancelado
# 4       Fijo           12   2021-11-14        2022-11-09  Cancelado
# 5   Variable           24   2021-02-23        2023-02-13    Vigente
# 6   Variable           12   2022-10-02        2023-09-27  Cancelado
# 7   Variable           60   2021-03-01        2026-02-03    Vigente
# 8       Fijo           60   2023-08-09        2028-07-13    Vigente
# 9       Fijo           24   2020-10-15        2022-10-05    Vigente
# 10  Variable           48   2023-06-09        2027-05-19  Cancelado
# 11  Variable            6   2024-02-17        2024-08-15  Cancelado
# 12      Fijo           60   2023-03-06        2028-02-08    Vigente
# 13      Fijo           48   2023-09-02        2027-08-12    Vigente
# 14  Variable           36   2021-09-04        2024-08-19    Vigente
# 15  Variable           60   2022-10-20        2027-09-24    Vigente
# 16      Fijo           48   2022-05-21        2026-04-30    Vigente
# 17  Variable            6   2023-08-02        2024-01-29    Vigente
# 18  Variable            6   2022-08-06        2023-02-02  Cancelado
# 19      Fijo           36   2021-05-03        2024-04-17    Vigente
# 20      Fijo           60   2022-10-08        2027-09-12    Vigente
# 21  Variable           36   2020-07-23        2023-07-08    Vigente
# 22  Variable           36   2022-03-31        2025-03-15    Vigente
# 23  Variable           60   2023-01-23        2027-12-28  Cancelado
# 24      Fijo           12   2022-08-04        2023-07-30    Vigente
# 25  Variable           12   2022-01-03        2022-12-29  Cancelado
# 26      Fijo           12   2023-11-24        2024-11-18  Cancelado
# 27      Fijo           12   2023-05-31        2024-05-25    Vigente
# 28      Fijo           48   2024-02-29        2028-02-08    Vigente
# 29      Fijo           36   2021-03-10        2024-02-23    Vigente

# %% [markdown]
# ### Algoritmo X-otros activos corrientes

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Lista personalizada de descripciones reales en español
frases = [
    "Pago anticipado por servicios contratados",
    "Depósito en garantía para contrato vigente",
    "Valores a cobrar por ventas a crédito",
    "Documentos por cobrar pendientes de pago",
    "Gastos pagados por anticipado de seguros",
    "Anticipo a proveedor por compra de insumos",
    "Crédito otorgado por devolución de impuestos",
    "Depósito en garantía para servicios públicos",
    "Pago anticipado por publicidad contratada",
    "Anticipo para adquisición de maquinaria"
]

# Inicialización
np.random.seed(321)
random.seed(321)
fake = Faker('es_ES')
Faker.seed(321)

# Parámetros
num_registros = 30
tipos_activos = [
    'Anticipo a proveedores',
    'Depósitos en garantía',
    'Valores a cobrar',
    'Documentos por cobrar',
    'Otros créditos',
    'Gastos pagados por anticipado'
]

monedas = ['ARS', 'USD', 'EUR']

# Generar datos
activos_corrientes = []

for i in range(num_registros):
    tipo = random.choice(tipos_activos)
    monto = round(random.uniform(1000, 200000), 2)
    moneda = random.choice(monedas)
    fecha_registro = fake.date_between(start_date='-90d', end_date='today')
    descripcion = random.choice(frases)  # <- Aquí está corregido

    activos_corrientes.append({
        'id_activo_corriente': f'AC-{1000 + i}',
        'tipo_activo': tipo,
        'monto': monto,
        'moneda': moneda,
        'fecha_registro': fecha_registro,
        'descripcion': descripcion
    })

# Crear DataFrame
df_activos_corrientes = pd.DataFrame(activos_corrientes)

# Guardar si querés
df_activos_corrientes.to_csv("otros_activos_corrientes.csv", index=False)

# Mostrar ejemplo
df_activos_corrientes
# Out:
#    id_activo_corriente                    tipo_activo      monto moneda  \
# 0              AC-1000               Valores a cobrar   78797.69    USD
# 1              AC-1001          Documentos por cobrar   68882.81    EUR
# 2              AC-1002                 Otros créditos   91532.93    EUR
# 3              AC-1003          Documentos por cobrar   45688.93    EUR
# 4              AC-1004          Documentos por cobrar  184298.15    ARS
# 5              AC-1005                 Otros créditos  174362.28    USD
# 6              AC-1006         Anticipo a proveedores   45006.03    USD
# 7              AC-1007  Gastos pagados por anticipado  161286.44    USD
# 8              AC-1008               Valores a cobrar   88954.56    USD
# 9              AC-1009  Gastos pagados por anticipado  184740.68    USD
# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicialización
fake = Faker('es_AR')
random.seed(42)
np.random.seed(42)
Faker.seed(42)

# Parámetros
num_equipos = 30

tipos_maquinaria = [
    "Torno CNC", "Fresadora", "Impresora industrial", "Camión", "Grua hidráulica",
    "Montacargas", "Generador eléctrico", "Sistema de climatización", "Soldadora MIG", "Compresor de aire"
]

ubicaciones = ["Planta A", "Planta B", "Depósito Central", "Taller de Mantenimiento"]
estados = ["Operativo", "En reparación", "Fuera de servicio", "Pendiente de baja"]

# Generar datos
maquinarias = []

for i in range(num_equipos):
    tipo = random.choice(tipos_maquinaria)
    id_equipo = f"EQ-{1000 + i}"
    descripcion = f"{tipo} modelo {fake.bothify(text='???-####')}"
    ubicacion = random.choice(ubicaciones)
    estado = random.choices(estados, weights=[0.7, 0.15, 0.1, 0.05])[0]
    fecha_adquisicion = fake.date_between(start_date='-10y', end_date='-1y')
    valor_adquisicion = round(random.uniform(200000, 5000000), 2)
    vida_util_anios = random.randint(5, 15)
    fecha_fin_vida = fecha_adquisicion + timedelta(days=vida_util_anios * 365)

    maquinarias.append({
        "id_equipo": id_equipo,
        "tipo_equipo": tipo,
        "descripcion": descripcion,
        "ubicacion": ubicacion,
        "estado": estado,
        "fecha_adquisicion": fecha_adquisicion,
        "valor_adquisicion": valor_adquisicion,
        "vida_util_anios": vida_util_anios,
        "fecha_fin_vida_util": fecha_fin_vida
    })

# Crear DataFrame
df_maquinarias = pd.DataFrame(maquinarias)

# Guardar si querés
df_maquinarias.to_csv("inventario_maquinarias.csv", index=False)

# Mostrar muestra
df_maquinarias
# Out:
#    id_equipo               tipo_equipo  \
# 0    EQ-1000                 Fresadora
# 1    EQ-1001                 Fresadora
# 2    EQ-1002                    Camión
# 3    EQ-1003             Soldadora MIG
# 4    EQ-1004      Impresora industrial
# 5    EQ-1005                 Fresadora
# 6    EQ-1006         Compresor de aire
# 7    EQ-1007                 Fresadora
# 8    EQ-1008         Compresor de aire
# 9    EQ-1009                    Camión
# 10   EQ-1010       Generador eléctrico
# 11   EQ-1011               Montacargas
# 12   EQ-1012                 Fresadora
# 13   EQ-1013       Generador eléctrico
# 14   EQ-1014                    Camión
# 15   EQ-1015                 Torno CNC
# 16   EQ-1016               Montacargas
# 17   EQ-1017  Sistema de climatización
# 18   EQ-1018             Soldadora MIG
# 19   EQ-1019       Generador eléctrico
# 20   EQ-1020  Sistema de climatización
# 21   EQ-1021      Impresora industrial
# 22   EQ-1022  Sistema de climatización
# 23   EQ-1023                 Fresadora
# 24   EQ-1024       Generador eléctrico
# 25   EQ-1025             Soldadora MIG
# 26   EQ-1026           Grua hidráulica
# 27   EQ-1027             Soldadora MIG
# 28   EQ-1028               Montacargas
# 29   EQ-1029                 Fresadora
#
#                                  descripcion                ubicacion  \
# 0                  Fresadora modelo oiV-1043                 Planta A
# 1                  Fresadora modelo cbf-8196                 Planta A
# 2                     Camión modelo mTP-8908                 Planta B
# 3              Soldadora MIG modelo rZa-6379  Taller de Mantenimiento
# 4       Impresora industrial modelo jnW-2654  Taller de Mantenimiento
# 5                  Fresadora modelo wMq-1615                 Planta A
# 6          Compresor de aire modelo fJs-7816         Depósito Central
# 7                  Fresadora modelo Tec-9593  Taller de Mantenimiento
# 8          Compresor de aire modelo yrD-4131         Depósito Central
# 9                     Camión modelo nQr-5255         Depósito Central
# 10       Generador eléctrico modelo Upk-1928         Depósito Central
# 11               Montacargas modelo XXd-4835         Depósito Central
# 12                 Fresadora modelo enK-0564                 Planta B
# 13       Generador eléctrico modelo PDj-5376         Depósito Central
# 14                    Camión modelo VLB-3884         Depósito Central
# 15                 Torno CNC modelo GFf-6532         Depósito Central
# 16               Montacargas modelo Mey-1226                 Planta B
# 17  Sistema de climatización modelo aRU-7848                 Planta B
# 18             Soldadora MIG modelo sBk-8451         Depósito Central
# 19       Generador eléctrico modelo gOt-4828         Depósito Central
# 20  Sistema de climatización modelo xWk-8932                 Planta A
# 21      Impresora industrial modelo Fbh-8095  Taller de Mantenimiento
# 22  Sistema de climatización modelo Kff-4303         Depósito Central
# 23                 Fresadora modelo QEJ-1822         Depósito Central
# 24       Generador eléctrico modelo IWU-8963                 Planta B
# 25             Soldadora MIG modelo HCh-4657                 Planta B
# 26           Grua hidráulica modelo JoL-1509                 Planta B
# 27             Soldadora MIG modelo cve-1031                 Planta A
# 28               Montacargas modelo iUK-4738         Depósito Central
# 29                 Fresadora modelo ggQ-3763                 Planta A
#
#                estado fecha_adquisicion  valor_adquisicion  vida_util_anios  \
# 0       En reparación        2016-06-06         1375480.90                7
# 1           Operativo        2017-06-23          352556.86                6
# 2           Operativo        2021-10-27          327372.65                8
# 3           Operativo        2022-05-04         3028475.28                5
# 4           Operativo        2018-07-16          946301.60               10
# 5           Operativo        2022-10-10         1923101.03               10
# 6       En reparación        2022-12-22         3702712.58               13
# 7           Operativo        2021-06-17         1607255.75               15
# 8           Operativo        2021-03-25         3581944.81                5
# 9   Pendiente de baja        2021-10-28         4305525.06                6
# 10          Operativo        2019-09-02         4203730.05                7
# 11          Operativo        2017-07-27         1481493.55               15
# 12          Operativo        2023-05-25         1375092.44               12
# 13  Pendiente de baja        2017-11-22         3271998.85               13
# 14      En reparación        2023-08-04         3924799.58                8
# 15          Operativo        2022-04-24          517705.31               14
# 16          Operativo        2018-12-11         2099033.13               15
# 17          Operativo        2016-07-16         1383812.04               13
# 18      En reparación        2019-08-05         2256482.37               14
# 19          Operativo        2023-01-31         4988180.51               13
# 20      En reparación        2020-05-12         4333293.97                7
# 21          Operativo        2023-11-14         2046883.10               14
# 22  Pendiente de baja        2022-02-04         4331742.57                5
# 23      En reparación        2016-12-29         1832842.27                9
# 24          Operativo        2021-09-19         4778316.45                9
# 25          Operativo        2017-09-27          710771.95               15
# 26          Operativo        2017-06-28         3860051.84               13
# 27          Operativo        2020-02-20         2545307.40                6
# 28          Operativo        2020-09-11         1356183.64               14
# 29      En reparación        2019-05-22         4116911.62               13
#
#    fecha_fin_vida_util
# 0           2023-06-05
# 1           2023-06-22
# 2           2029-10-25
# 3           2027-05-03
# 4           2028-07-13
# 5           2032-10-07
# 6           2035-12-19
# 7           2036-06-13
# 8           2026-03-24
# 9           2027-10-27
# 10          2026-08-31
# 11          2032-07-23
# 12          2035-05-22
# 13          2030-11-19
# 14          2031-08-02
# 15          2036-04-20
# 16          2033-12-07
# 17          2029-07-13
# 18          2033-08-01
# 19          2036-01-28
# 20          2027-05-11
# 21          2037-11-10
# 22          2027-02-03
# 23          2025-12-27
# 24          2030-09-17
# 25          2032-09-23
# 26          2030-06-25
# 27          2026-02-18
# 28          2034-09-08
# 29          2032-05-18

# %% [markdown]
# ### Algoritmo XII

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicializar Faker y semillas
fake = Faker('es_AR')
random.seed(101)
np.random.seed(101)
Faker.seed(101)

# Parámetros
num_inmuebles = 30

tipos_inmuebles = [
    "Oficina", "Depósito", "Terreno", "Planta industrial",
    "Local comercial", "Edificio", "Galpón", "Centro logístico"
]

estados_inmueble = ["Operativo", "Arrendado", "Mantenimiento", "Disponible", "Inactivo"]
ubicaciones = ["CABA", "Gran Buenos Aires", "Córdoba", "Mendoza", "Rosario", "Neuquén", "Salta"]

# Generar datos
inmuebles = []

for i in range(num_inmuebles):
    tipo = random.choice(tipos_inmuebles)
    direccion = fake.address().replace("\n", ", ")
    ciudad = random.choice(ubicaciones)
    estado = random.choices(estados_inmueble, weights=[0.5, 0.2, 0.1, 0.1, 0.1])[0]
    fecha_adquisicion = fake.date_between(start_date='-25y', end_date='-2y')
    valor_adquisicion = round(random.uniform(1.0, 150.0), 2)
    superficie_m2 = round(random.uniform(100.0, 5000.0), 2)
    id_inmueble = f"INM-{1000 + i}"

    inmuebles.append({
        "id_inmueble": id_inmueble,
        "tipo_inmueble": tipo,
        "direccion": direccion,
        "ciudad": ciudad,
        "estado": estado,
        "fecha_adquisicion": fecha_adquisicion,
        "valor_adquisicion": valor_adquisicion,
        "superficie_m2": superficie_m2
    })

# Crear DataFrame
df_inmuebles = pd.DataFrame(inmuebles)

# Guardar como CSV si lo necesitás
df_inmuebles.to_csv("inventario_inmuebles.csv", index=False)

# Mostrar ejemplo
df_inmuebles
# Out:
#    id_inmueble      tipo_inmueble  \
# 0     INM-1000  Planta industrial
# 1     INM-1001  Planta industrial
# 2     INM-1002  Planta industrial
# 3     INM-1003           Depósito
# 4     INM-1004           Edificio
# 5     INM-1005             Galpón
# 6     INM-1006           Edificio
# 7     INM-1007  Planta industrial
# 8     INM-1008   Centro logístico
# 9     INM-1009           Edificio
# 10    INM-1010             Galpón
# 11    INM-1011           Edificio
# 12    INM-1012    Local comercial
# 13    INM-1013            Oficina
# 14    INM-1014   Centro logístico
# 15    INM-1015   Centro logístico
# 16    INM-1016  Planta industrial
# 17    INM-1017            Terreno
# 18    INM-1018           Depósito
# 19    INM-1019            Oficina
# 20    INM-1020            Terreno
# 21    INM-1021           Edificio
# 22    INM-1022            Oficina
# 23    INM-1023            Oficina
# 24    INM-1024  Planta industrial
# 25    INM-1025            Terreno
# 26    INM-1026            Oficina
# 27    INM-1027           Depósito
# 28    INM-1028  Planta industrial
# 29    INM-1029  Planta industrial
#
#                                             direccion             ciudad  \
# 0       Diagonal Rawson N° 844, Neuquén 8300, Neuquén            Rosario
# 1   Diagonal 6 N° 64 Piso 5 Dto. 4, La Rioja 5300,...            Rosario
# 2   Avenida Salta N° 7574, San Salvador de Jujuy 4...            Córdoba
# 3    Calle 1 N° 155, Mar del Plata 7600, Buenos Aires            Mendoza
# 4   Calle 6 N° 3987, San Ferando del Valle de Cata...  Gran Buenos Aires
# 21      Operativo        2000-07-27              98.34        4449.12
# 22      Arrendado        2016-04-01             128.65        2348.22
# 23      Operativo        2016-11-28             118.84        2409.15
# 24      Arrendado        2014-10-20              47.99         190.76
# 25      Operativo        2018-07-19              55.29        2075.88
# 26      Operativo        2019-05-17              10.88         825.82
# 27      Operativo        2004-10-29              56.12        2292.18
# 28      Arrendado        2018-09-28             123.66        2614.48
# 29      Operativo        2022-01-05              83.86        1571.01

# %% [markdown]
# ### Algoritmo XIII-activos no corrientes

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# Inicializar Faker y semillas
fake = Faker('es_AR')
random.seed(202)
np.random.seed(202)
Faker.seed(202)

# Lista de ejemplos de activos no corrientes
tipos_activos = [
    "Créditos a largo plazo",
    "Depósitos judiciales",
    "Préstamos otorgados a socios",
    "Inversiones permanentes",
    "Activos intangibles",
    "Costos diferidos",
    "Bienes de uso en desuso",
    "Licencias y patentes"
]

monedas = ["ARS", "USD", "EUR"]
estados = ["Activo", "Revaluado", "En litigio", "Depreciado", "Pendiente de baja"]

# Frases de descripción en español
descripciones = [
    "Inversión en empresa vinculada",
    "Depósito judicial en garantía por litigio",
    "Préstamo otorgado con vencimiento a largo plazo",
    "Crédito documentado con garantía hipotecaria",
    "Patente tecnológica adquirida para desarrollo",
    "Costo de instalación pendiente de amortización",
    "Activos intangibles no amortizados",
    "Licencia de software con vigencia extendida"
]

# Generar dataset
otros_activos = []
num_registros = 30

for i in range(num_registros):
    tipo = random.choice(tipos_activos)
    descripcion = random.choice(descripciones)
    moneda = random.choice(monedas)
    estado = random.choice(estados)
    fecha_registro = fake.date_between(start_date='-10y', end_date='-1y')
    valor_millones = round(random.uniform(1.0, 80.0), 2)
    id_activo = f"ANC-{1000 + i}"

    otros_activos.append({
        "id_activo": id_activo,
        "tipo_activo": tipo,
        "descripcion": descripcion,
        "moneda": moneda,
        "estado": estado,
        "fecha_registro": fecha_registro,
        "valor_millones": valor_millones
    })

# Crear DataFrame
df_activos_no_corrientes = pd.DataFrame(otros_activos)


# Guardar si querés
df_activos_no_corrientes.to_csv("otros_activos_no_corrientes.csv", index=False)
df_activos_no_corrientes
# Out:
#    id_activo                   tipo_activo  \
# 0   ANC-1000       Bienes de uso en desuso
# 1   ANC-1001       Bienes de uso en desuso
# 2   ANC-1002        Créditos a largo plazo
# 3   ANC-1003       Inversiones permanentes
# 4   ANC-1004          Licencias y patentes
# 5   ANC-1005          Licencias y patentes
# 6   ANC-1006  Préstamos otorgados a socios
# 7   ANC-1007  Préstamos otorgados a socios
# 8   ANC-1008       Inversiones permanentes
# 9   ANC-1009              Costos diferidos
# 10  ANC-1010          Licencias y patentes
# 11  ANC-1011       Bienes de uso en desuso
# 12  ANC-1012       Bienes de uso en desuso
# 13  ANC-1013              Costos diferidos
# 14  ANC-1014          Depósitos judiciales
# 15  ANC-1015  Préstamos otorgados a socios
# 16  ANC-1016           Activos intangibles
# 17  ANC-1017          Licencias y patentes
# 18  ANC-1018  Préstamos otorgados a socios
# 19  ANC-1019  Préstamos otorgados a socios
# 20  ANC-1020  Préstamos otorgados a socios
# 21  ANC-1021        Créditos a largo plazo
